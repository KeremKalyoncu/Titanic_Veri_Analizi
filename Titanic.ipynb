# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic.csv")

# %% [markdown]
# # Veriyi Düzenleme ve Basit Sorgular

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# # Gemide Yaşayanların Oranı

# %%
x = len(df[df["Survived"] == 1])
y = len(df[df["Survived"] == 0])
d = (x / ((x+y) / 100))

# %%
df1 = pd.DataFrame({"Yaşayanlar": [x] , "Ölenler": [y] , "Yaşayan Oranı": [d]})
df1
# Out:
#    Yaşayanlar  Ölenler  Yaşayan Oranı
# 0         152      266      36.363636

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# #Bilet Türüne Göre Yaşayanlar Yaşamayanlar

# %%
ct = pd.crosstab(df["Pclass"], df["Survived"])
ct.columns = ["Ölenler", "Yaşayanlar"]
ct
# Out:
#         Ölenler  Yaşayanlar
# Pclass
# 1            57          50
# 2            63          30
# 3           146          72

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#Yaş Kolonlarındaki Boşlukları Kolonun Ortalamasına Eşitlemek

df["Age"].fillna(df["Age"].mean(), inplace=True)
# Out:
# /tmp/ipython-input-3073619436.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(), inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
# Yaş kolonunu düzenleme ve İndexleri PassengerId yaparak DataFrami düzenlemek

df["Age"] = df["Age"].round(1)
df.set_index("PassengerId",inplace=True)

# %%
df
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
# Kabin kolonu gerekli veriyi vermediği ve fazla boş değer olduğundan ötürü siliyorum

df.drop("Cabin",axis=1,inplace=True)
df
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# # Çocuk Sayısına Göre Kurtulma Sayıları

# %%
ck = df.groupby("SibSp").sum()["Survived"]
ck
# Out:
# SibSp
# 0    88
# 1    54
# 2     6
# 3     1
# 4     1
# 5     1
# 8     1
# Name: Survived, dtype: int64

# %%
df
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# # Kurtulanların Ve Ölenlerin Yaş Ortalamaları

# %%
ol = df[df.Survived == 0]["Age"].mean()
ya = df[df.Survived == 1]["Age"].mean()
df_kon = pd.DataFrame({"Ölenler": [ol], "Yaşayanlar": [ya]})
df_kon
# Out:
#      Ölenler  Yaşayanlar
# 0  30.278947   30.276974

# %%
df
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# # **Görselleştirme**

# %%
sns.set_style("whitegrid")

# %% [markdown]
# # Hayatta kalanla ile Kalmayanların Sayıları

# %%
# Hayatta kalanla ile Kalmayanların Sayıları

sns.countplot(data=df,x="Survived")
plt.show()

# %% [markdown]
# # Ölenler İle Yaşayanların Ortalama Yaşları

# %%
# Ölenler İle Yaşayanların Ortalama Yaşları

sns.barplot(data=df,x="Survived",y="Age")
plt.show()

# %%
df
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %% [markdown]
# # Limana Göre Hayatta Kalma Ölme Sayıları

# %%
sns.countplot(data=df,x="Embarked",hue="Survived")
plt.show()

# %% [markdown]
# # Bilet Alan Kişilerin Kaç Çocuğu Var

# %%
sns.countplot(data=df,x="Pclass",hue="SibSp")
plt.show()

# %% [markdown]
# # Hayatta Kalıp Kalmama Tahmini

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
df.drop(columns=["Name","Ticket","Embarked","Fare"],inplace=True)

# %%
df
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch
# PassengerId
# 892                 0       3    male  34.5      0      0
# 893                 1       3  female  47.0      1      0
# 894                 0       2    male  62.0      0      0
# 895                 0       3    male  27.0      0      0
# 896                 1       3  female  22.0      1      1
# ...               ...     ...     ...   ...    ...    ...
# 1305                0       3    male  30.3      0      0
# 1306                1       1  female  39.0      0      0
# 1307                0       3    male  38.5      0      0
# 1308                0       3    male  30.3      0      0
# 1309                0       3    male  30.3      1      1
#
# [418 rows x 6 columns]

# %%
df["Sex"] = pd.get_dummies(df["Sex"],drop_first=True)

# %%
df
# Out:
#              Survived  Pclass    Sex   Age  SibSp  Parch
# PassengerId
# 892                 0       3   True  34.5      0      0
# 893                 1       3  False  47.0      1      0
# 894                 0       2   True  62.0      0      0
# 895                 0       3   True  27.0      0      0
# 896                 1       3  False  22.0      1      1
# ...               ...     ...    ...   ...    ...    ...
# 1305                0       3   True  30.3      0      0
# 1306                1       1  False  39.0      0      0
# 1307                0       3   True  38.5      0      0
# 1308                0       3   True  30.3      0      0
# 1309                0       3   True  30.3      1      1
#
# [418 rows x 6 columns]

# %%
x = df.drop("Survived",axis=1)
y = df["Survived"]

x_train , x_test, y_train , y_test = train_test_split(x,y,train_size=0.75,random_state=53)

# %%
log = LogisticRegression()
model = log.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 1.0

# %%
# 1 olması iyi gibi ama overfitting olma durumu olabilir bi bakalım

# %%
model.predict([[1,0,39,0,0]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# veri içinde öğrendiği verideki kişi ölmüş ama o yaşıyor diyor bunu düzeltmek için tree algoritmasınıa geçebiliriz

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from types import new_class
rdr = RandomForestClassifier(n_estimators=100)
model2 = rdr.fit(x_train,y_train)
model2.score(x_train,y_train)
# Out:
# 1.0

# %%
model.predict([[1,0,39,0,0]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
# Verinin Azlığından dolayı güzel bir tahmin yapamıyor program ve overfitting yaşıyor

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,model.predict(x_test))
# Out:
# 1.0
